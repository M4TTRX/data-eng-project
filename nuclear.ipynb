# %%
import csv
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn'

# %%
data_1 = pd.read_csv('./dags/data/ingestion/nuclear.csv',error_bad_lines=False,sep=';')
data_1 = data_1.drop(columns={'reserve_secondaire_maximale','puissance_minimum_de_conception','sub_sector','perimetre_spatial','combustible','filiere','unite'})
data_1 = data_1.rename(columns={'centrale':'plant','sous_filiere':'sub_sector','contrat_programme':'contract','point_gps_wsg84':'position','commune':'city','date_de_mise_en_service_industrielle':'start_date','puissance_installee':'power (MW)'})
data_1
# Out:
# C:\Users\ewenc\AppData\Local\Temp\ipykernel_13784\977861297.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data_1 = pd.read_csv('./dags/data/ingestion/nuclear.csv',error_bad_lines=False,sep=';')
#                     plant         tranche   sector  \
# 0              BELLEVILLE    BELLEVILLE 1  Nuclear
# 1              BELLEVILLE    BELLEVILLE 2  Nuclear
# 2            BLAYAIS (LE)       BLAYAIS 1  Nuclear
# 3            BLAYAIS (LE)       BLAYAIS 2  Nuclear
# 4            BLAYAIS (LE)       BLAYAIS 3  Nuclear
# 5            BLAYAIS (LE)       BLAYAIS 4  Nuclear
# 6              BUGEY (LE)         BUGEY 2  Nuclear
# 7              BUGEY (LE)         BUGEY 3  Nuclear
# 8              BUGEY (LE)         BUGEY 4  Nuclear
# 9              BUGEY (LE)         BUGEY 5  Nuclear
# 10               CATTENOM      CATTENOM 1  Nuclear
# 11               CATTENOM      CATTENOM 2  Nuclear
# ...

# %%
# Out:
#                     plant       type                  gps
# 0              BELLEVILLE  Nucléaire   47.508946,2.875676
# 1              BELLEVILLE  Nucléaire   47.508946,2.875676
# 2            BLAYAIS (LE)  Nucléaire  45.257605,-0.690606
# 3            BLAYAIS (LE)  Nucléaire  45.257605,-0.690606
# 4            BLAYAIS (LE)  Nucléaire  45.257605,-0.690606
# 5            BLAYAIS (LE)  Nucléaire  45.257605,-0.690606
# 6              BUGEY (LE)  Nucléaire   45.801148,5.266072
# 7              BUGEY (LE)  Nucléaire   45.801148,5.266072
# 8              BUGEY (LE)  Nucléaire   45.801148,5.266072
# 9              BUGEY (LE)  Nucléaire   45.801148,5.266072
# 10               CATTENOM  Nucléaire   49.415953,6.218271
# 11               CATTENOM  Nucléaire   49.415953,6.218271
# 12               CATTENOM  Nucléaire   49.415953,6.218271
# 13               CATTENOM  Nucléaire   49.415953,6.218271
# 14               CHINON B  Nucléaire   47.228727,0.168307
# ...
